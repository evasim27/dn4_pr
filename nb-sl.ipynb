# %% [markdown]
# ## Streamlit aplikacija
#
# Podatkovno rudarjenje, naloga, `1. 6. 2025`
# **`Eva Simonič`**
#
# Bonus domača naloga združuje vse pridobljeno znanje, ki ga boste implementirali z uporabo Streamlita. Vsaka kategorija vprašanj naj bo na svoji strani. Na koncu aplikacijo objavite na spletu, v ta repozitorij pa oddajte kratko poročilo.

# %% [markdown]
# ### Podatki
#
# Podatkovna zbirka MovieLens ostaja enaka kot pri ostalih nalogah.

# %% [markdown]
# ### Vprašanja
#
# #### 1.  Analiza podatkov (30%)
#
# Izpišite 10 filmov z najboljšo povprečno oceno. Poleg naslova filma izpišite tudi povprečno oceno in število ocen.
#
# Dodajte še sledeče interaktivne elemente:
# * izbira minimalnega števila ocen, ki so jih filmi dobili
# * izbira žanra
# * izbira leta
#
# Možna naj bo poljubna kombinacija filtrov. Uporabnik lahko na primer vpraša po najboljših akcijskih filmih z vsaj desetimi ocenami, ali pa po najboljših filmih leta 1998, ne glede na število ocen.
#
# #### 2. Primerjava dveh filmov (30%)
#
# Ko uporabnik izbere dva filma, naj se za ta dva filma prikažejo naslednje primerjave:
# * statistika ocen (povprečna ocena, število ocen, standardni odklon)
# * histogram ocen
# * graf povprečne letne ocene
# * graf števila ocen na leto
#
# #### 3. Priporočilni sistem (40%)
#
# Implementirajte registracijo in prijavo uporabnika v sistem ter sistem za priporočanje filmov.
#
# Samo prijavljen uporabnik lahko ocenjuje filme. Ko je uporabnik vnesel vsaj deset ocen, naj se mu izpiše deset priporočil.

# %% [markdown]
# ### Poročilo
#
# Delovanje aplikacije na kratko predstavite v poročilu. Opišite uporabo vaše aplikacije, ki naj vključuje tudi slike zaslona. Dodajte tudi povezavo do aktivne aplikacije in do repozitorija, kjer se nahaja koda.
#
# Rezultati naloge torej so:
# * poročilo (kratka navodila in slike)
# * povezava do izvorne kode aplikacije
# * povezava do aktivne aplikacije
#
# V aplikaciji Streamlit je možno na levi strani aplikacije izbrati, če želimo izpis 10 filmov z najboljšo povprečno oceno, glede na kriterije, ki smo jih izbrali, primerjava dveh filmov ali priporočilni sistem za filme. Ob izbiri strani 'Top 10 filmov', lahko izberemo minimalno število ocen, ki jih film mora imeti, žanr in leto filma. Nato se nam bo v tabeli prikazalo top 10 filmov, glede na naše kriterije.
#
# ![image.png](attachment:843f5df9-9f12-4a6d-a3e1-dc1d49de69d9.png)
#
# Ob izbiri strani 'Primerjava filmov', se nam bo prikazala stran, na kateri imamo možnost primerjati 2 filma med sabo. Najprej si izberemo, katera filma želimo primerjati. Ko naredimo to, se nam bo prikazala kratka statistika teh dveh filmov (število ocen, povprečna ocena in standardni odklon). Pod tem bodo razvidni 3 grafi in sicer histogram ocen, graf povprečne letne ocene in graf števila ocen na leto.
#
# ![image.png](attachment:f02ee492-0042-4549-ad3a-a977e26f9c05.png)
#
# ![image.png](attachment:fd50d1eb-fd30-4757-9b63-1105049291ab.png)
#
# ![image.png](attachment:ff54c61b-ca8d-4de0-a0cf-6dee4fe78712.png)
#
# ![image.png](attachment:03565183-a364-4137-a3e1-19a30d207537.png)
#
# Ob izbiri strani 'Priporočila', nas bo aplikacija najprej peljala na prijavo oz. registracijo. Če še nimamo profila, si ga moramo s klikom na 'Registracija' ustvariti in vpisati uporabniško ime in geslo. Ko smo to naredili, se lahko prijavimo. Da bi sistem za priporočila deloval, moramo najprej oceniti vsaj 10 filmov. Ko bomo to naredili, se nam bodo prikazala priporočila za filme v obliki tabele.
#
# ![image.png](attachment:5c3249c8-0cb0-48cd-9886-88caae4f64be.png)
#
# ![image.png](attachment:f0fd6599-e441-410b-9141-67d2cd7f24c0.png)
#
# ![image.png](attachment:1ca649d2-0966-4c24-85de-a7b1a2020366.png)

# %% [markdown]
# Povezava do izvorne kode aplikacije: https://github.com/PR-ULFRI/dn25-4-evasim27.git ; aplikacija je v datoteki app.py
#
# Povezava do aktivne aplikacije:
